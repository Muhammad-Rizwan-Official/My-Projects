# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
stock=pd.read_csv('nifty_500.csv')
stock
# Out:
#                                          Company Name      Symbol  \
# 0                                       3M India Ltd.     3MINDIA
# 1                                    Aarti Drugs Ltd.  AARTIDRUGS
# 2                               Aavas Financiers Ltd.       AAVAS
# 3                                      ABB India Ltd.         ABB
# 4                                   Abbott India Ltd.  ABBOTINDIA
# ..                                                ...         ...
# 496                           Zensar Technolgies Ltd.  ZENSARTECH
# 497  ZF Commercial Vehicle Control Systems India Ltd.   ZFCVINDIA
# 498                                       Zomato Ltd.      ZOMATO
# 499                           Zydus Lifesciences Ltd.   ZYDUSLIFE
# 500                               Zydus Wellness Ltd.   ZYDUSWELL
#
#                            Industry Series      Open      High       Low  \
# 0                       Diversified     EQ  21950.00  21999.00  21126.05
# ...

# %%
stock.head()
# Out:
#             Company Name      Symbol            Industry Series      Open  \
# 0          3M India Ltd.     3MINDIA         Diversified     EQ  21950.00
# 1       Aarti Drugs Ltd.  AARTIDRUGS          Healthcare     EQ    400.50
# 2  Aavas Financiers Ltd.       AAVAS  Financial Services     EQ   1997.10
# 3         ABB India Ltd.         ABB       Capital Goods     EQ   2260.35
# 4      Abbott India Ltd.  ABBOTINDIA          Healthcare     EQ  18700.40
#
#        High       Low  Previous Close  Last Traded Price   Change  \
# 0  21999.00  21126.05        21854.05           21575.00  -279.05
# 1    401.80    394.10          403.85             400.00    -3.85
# 2   2004.05   1894.50         2015.45            1943.15   -72.30
# 3   2311.50   2260.35         2300.90            2280.00   -20.90
# 4  19200.00  18605.00        18760.40           19199.80   439.40
#
#   Percentage Change  Share Volume  Value (Indian Rupee)  52 Week High  \
# ...

# %%
stock.tail()
# Out:
#                                          Company Name      Symbol  \
# 496                           Zensar Technolgies Ltd.  ZENSARTECH
# 497  ZF Commercial Vehicle Control Systems India Ltd.   ZFCVINDIA
# 498                                       Zomato Ltd.      ZOMATO
# 499                           Zydus Lifesciences Ltd.   ZYDUSLIFE
# 500                               Zydus Wellness Ltd.   ZYDUSWELL
#
#                            Industry Series     Open     High      Low  \
# 496          Information Technology     EQ   273.15   273.55   268.40
# 497  Automobile and Auto Components     EQ  7748.00  7900.00  7525.30
# 498               Consumer Services     EQ    54.15    56.70    52.55
# 499                      Healthcare     EQ   356.90   364.05   354.30
# 500      Fast Moving Consumer Goods     EQ  1635.00  1635.00  1605.00
#
#      Previous Close  Last Traded Price  Change Percentage Change  \
# 496          272.10              270.0   -2.10             -0.77
# ...

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               501 non-null    object
#  1   Symbol                     501 non-null    object
#  2   Industry                   501 non-null    object
#  3   Series                     501 non-null    object
#  4   Open                       501 non-null    float64
#  5   High                       501 non-null    float64
#  6   Low                        501 non-null    float64
#  7   Previous Close             501 non-null    float64
#  8   Last Traded Price          501 non-null    float64
#  9   Change                     501 non-null    object
#  10  Percentage Change          501 non-null    object
#  11  Share Volume               501 non-null    int64
#  12  Value (Indian Rupee)       501 non-null    float64
# ...

# %%
stock.describe()
# Out:
#                Open          High           Low  Previous Close  \
# count    501.000000    501.000000    501.000000      501.000000
# mean    1525.904491   1553.804990   1504.042415     1528.061277
# std     4466.627117   4576.377692   4435.492332     4477.209376
# min        6.750000      6.950000      6.700000        6.850000
# 25%      215.300000    221.550000    210.600000      217.200000
# 50%      551.100000    569.100000    547.000000      554.750000
# 75%     1404.500000   1421.250000   1396.850000     1411.700000
# max    70300.000000  72500.000000  70300.000000    70800.900000
#
#        Last Traded Price  Share Volume  Value (Indian Rupee)  52 Week High  \
# count         501.000000  5.010000e+02          5.010000e+02    501.000000
# mean         1536.925449  2.580350e+06          8.635146e+08   2182.632196
# std          4532.004734  9.407021e+06          4.335973e+09   5728.930152
# min             6.800000  1.507000e+03          2.587223e+06     13.100000
# ...

# %%
stock.isnull().sum()
# Out:
# Company Name                 0
# Symbol                       0
# Industry                     0
# Series                       0
# Open                         0
# High                         0
# Low                          0
# Previous Close               0
# Last Traded Price            0
# Change                       0
# Percentage Change            0
# Share Volume                 0
# Value (Indian Rupee)         0
# 52 Week High                 0
# 52 Week Low                  0
# 365 Day Percentage Change    0
# 30 Day Percentage Change     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
stock['Industry']=le.fit_transform(stock['Industry'])
stock
# Out:
#                                          Company Name      Symbol  Industry  \
# 0                                       3M India Ltd.     3MINDIA         7
# 1                                    Aarti Drugs Ltd.  AARTIDRUGS        11
# 2                               Aavas Financiers Ltd.       AAVAS         9
# 3                                      ABB India Ltd.         ABB         1
# 4                                   Abbott India Ltd.  ABBOTINDIA        11
# ..                                                ...         ...       ...
# 496                           Zensar Technolgies Ltd.  ZENSARTECH        12
# 497  ZF Commercial Vehicle Control Systems India Ltd.   ZFCVINDIA         0
# 498                                       Zomato Ltd.      ZOMATO         6
# 499                           Zydus Lifesciences Ltd.   ZYDUSLIFE        11
# 500                               Zydus Wellness Ltd.   ZYDUSWELL         8
#
# ...

# %%
stock['Symbol']=le.fit_transform(stock['Symbol'])
stock
# Out:
#                                          Company Name  Symbol  Industry  \
# 0                                       3M India Ltd.       0         7
# 1                                    Aarti Drugs Ltd.       1        11
# 2                               Aavas Financiers Ltd.       2         9
# 3                                      ABB India Ltd.       3         1
# 4                                   Abbott India Ltd.       4        11
# ..                                                ...     ...       ...
# 496                           Zensar Technolgies Ltd.     496        12
# 497  ZF Commercial Vehicle Control Systems India Ltd.     497         0
# 498                                       Zomato Ltd.     498         6
# 499                           Zydus Lifesciences Ltd.     499        11
# 500                               Zydus Wellness Ltd.     500         8
#
#     Series      Open      High       Low  Previous Close  Last Traded Price  \
# ...

# %%
stock['Company Name']=le.fit_transform(stock['Company Name'])
stock
# Out:
#      Company Name  Symbol  Industry Series      Open      High       Low  \
# 0               0       0         7     EQ  21950.00  21999.00  21126.05
# 1               6       1        11     EQ    400.50    401.80    394.10
# 2               7       2         9     EQ   1997.10   2004.05   1894.50
# 3               1       3         1     EQ   2260.35   2311.50   2260.35
# 4               8       4        11     EQ  18700.40  19200.00  18605.00
# ..            ...     ...       ...    ...       ...       ...       ...
# 496           496     496        12     EQ    273.15    273.55    268.40
# 497           494     497         0     EQ   7748.00   7900.00   7525.30
# 498           497     498         6     EQ     54.15     56.70     52.55
# 499           498     499        11     EQ    356.90    364.05    354.30
# 500           499     500         8     EQ   1635.00   1635.00   1605.00
#
#      Previous Close  Last Traded Price   Change Percentage Change  \
# ...

# %%
stock['Series']=le.fit_transform(stock['Series'])
stock
# Out:
#      Company Name  Symbol  Industry  Series      Open      High       Low  \
# 0               0       0         7       1  21950.00  21999.00  21126.05
# 1               6       1        11       1    400.50    401.80    394.10
# 2               7       2         9       1   1997.10   2004.05   1894.50
# 3               1       3         1       1   2260.35   2311.50   2260.35
# 4               8       4        11       1  18700.40  19200.00  18605.00
# ..            ...     ...       ...     ...       ...       ...       ...
# 496           496     496        12       1    273.15    273.55    268.40
# 497           494     497         0       1   7748.00   7900.00   7525.30
# 498           497     498         6       1     54.15     56.70     52.55
# 499           498     499        11       1    356.90    364.05    354.30
# 500           499     500         8       1   1635.00   1635.00   1605.00
#
#      Previous Close  Last Traded Price   Change Percentage Change  \
# ...

# %%
stock['Series']=le.fit_transform(stock['Series'])
stock

# %%
stock['Change']=le.fit_transform(stock['Change'])
stock
# Out:
#      Company Name  Symbol  Industry  Series      Open      High       Low  \
# 0               0       0         7       1  21950.00  21999.00  21126.05
# 1               6       1        11       1    400.50    401.80    394.10
# 2               7       2         9       1   1997.10   2004.05   1894.50
# 3               1       3         1       1   2260.35   2311.50   2260.35
# 4               8       4        11       1  18700.40  19200.00  18605.00
# ..            ...     ...       ...     ...       ...       ...       ...
# 496           496     496        12       1    273.15    273.55    268.40
# 497           494     497         0       1   7748.00   7900.00   7525.30
# 498           497     498         6       1     54.15     56.70     52.55
# 499           498     499        11       1    356.90    364.05    354.30
# 500           499     500         8       1   1635.00   1635.00   1605.00
#
#      Previous Close  Last Traded Price  Change Percentage Change  \
# ...

# %%
stock['Percentage Change']=le.fit_transform(stock['Percentage Change'])
stock
# Out:
#      Company Name  Symbol  Industry  Series      Open      High       Low  \
# 0               0       0         7       1  21950.00  21999.00  21126.05
# 1               6       1        11       1    400.50    401.80    394.10
# 2               7       2         9       1   1997.10   2004.05   1894.50
# 3               1       3         1       1   2260.35   2311.50   2260.35
# 4               8       4        11       1  18700.40  19200.00  18605.00
# ..            ...     ...       ...     ...       ...       ...       ...
# 496           496     496        12       1    273.15    273.55    268.40
# 497           494     497         0       1   7748.00   7900.00   7525.30
# 498           497     498         6       1     54.15     56.70     52.55
# 499           498     499        11       1    356.90    364.05    354.30
# 500           499     500         8       1   1635.00   1635.00   1605.00
#
#      Previous Close  Last Traded Price  Change  Percentage Change  \
# ...

# %%
stock['365 Day Percentage Change']=le.fit_transform(stock['365 Day Percentage Change'])
stock
# Out:
#      Company Name  Symbol  Industry  Series      Open      High       Low  \
# 0               0       0         7       1  21950.00  21999.00  21126.05
# 1               6       1        11       1    400.50    401.80    394.10
# 2               7       2         9       1   1997.10   2004.05   1894.50
# 3               1       3         1       1   2260.35   2311.50   2260.35
# 4               8       4        11       1  18700.40  19200.00  18605.00
# ..            ...     ...       ...     ...       ...       ...       ...
# 496           496     496        12       1    273.15    273.55    268.40
# 497           494     497         0       1   7748.00   7900.00   7525.30
# 498           497     498         6       1     54.15     56.70     52.55
# 499           498     499        11       1    356.90    364.05    354.30
# 500           499     500         8       1   1635.00   1635.00   1605.00
#
#      Previous Close  Last Traded Price  Change  Percentage Change  \
# ...

# %%
stock['30 Day Percentage Change']=le.fit_transform(stock['30 Day Percentage Change'])
stock
# Out:
#      Company Name  Symbol  Industry  Series      Open      High       Low  \
# 0               0       0         7       1  21950.00  21999.00  21126.05
# 1               6       1        11       1    400.50    401.80    394.10
# 2               7       2         9       1   1997.10   2004.05   1894.50
# 3               1       3         1       1   2260.35   2311.50   2260.35
# 4               8       4        11       1  18700.40  19200.00  18605.00
# ..            ...     ...       ...     ...       ...       ...       ...
# 496           496     496        12       1    273.15    273.55    268.40
# 497           494     497         0       1   7748.00   7900.00   7525.30
# 498           497     498         6       1     54.15     56.70     52.55
# 499           498     499        11       1    356.90    364.05    354.30
# 500           499     500         8       1   1635.00   1635.00   1605.00
#
#      Previous Close  Last Traded Price  Change  Percentage Change  \
# ...

# %%
x=stock.drop(['Previous Close'],axis=1)
x
# Out:
#      Company Name  Symbol  Industry  Series      Open      High       Low  \
# 0               0       0         7       1  21950.00  21999.00  21126.05
# 1               6       1        11       1    400.50    401.80    394.10
# 2               7       2         9       1   1997.10   2004.05   1894.50
# 3               1       3         1       1   2260.35   2311.50   2260.35
# 4               8       4        11       1  18700.40  19200.00  18605.00
# ..            ...     ...       ...     ...       ...       ...       ...
# 496           496     496        12       1    273.15    273.55    268.40
# 497           494     497         0       1   7748.00   7900.00   7525.30
# 498           497     498         6       1     54.15     56.70     52.55
# 499           498     499        11       1    356.90    364.05    354.30
# 500           499     500         8       1   1635.00   1635.00   1605.00
#
#      Last Traded Price  Change  Percentage Change  Share Volume  \
# ...

# %%
y=stock['Previous Close']
y
# Out:
# 0      21854.05
# 1        403.85
# 2       2015.45
# 3       2300.90
# 4      18760.40
#          ...
# 496      272.10
# 497     7716.60
# 498       53.85
# 499      357.00
# 500     1636.85
# Name: Previous Close, Length: 501, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               501 non-null    int32
#  1   Symbol                     501 non-null    int32
#  2   Industry                   501 non-null    int32
#  3   Series                     501 non-null    int32
#  4   Open                       501 non-null    float64
#  5   High                       501 non-null    float64
#  6   Low                        501 non-null    float64
#  7   Last Traded Price          501 non-null    float64
#  8   Change                     501 non-null    int32
#  9   Percentage Change          501 non-null    int32
#  10  Share Volume               501 non-null    int64
#  11  Value (Indian Rupee)       501 non-null    float64
#  12  52 Week High               501 non-null    float64
# ...

# %%
li=LinearRegression()

# %%
li.fit(X_train,y_train)
X_train_pred=li.predict(X_train)
score=metrics.r2_score(y_train,X_train_pred)
print('accuracy score of trained data:',score)

li.fit(X_test,y_test)
X_test_pred=li.predict(X_test)
score=metrics.r2_score(y_test,X_test_pred)
print('accuracy score of test data:',score)
# Out:
# accuracy score of trained data: 0.9999883318269013
# accuracy score of test data: 0.9999995508081135

# %%
tree=DecisionTreeRegressor()

# %%
tree.fit(X_train,y_train)
X_train_pred=tree.predict(X_train)
score=metrics.r2_score(y_train,X_train_pred)
print('accuracy score of trained data:',score)

tree.fit(X_test,y_test)
X_test_pred=tree.predict(X_test)
score=metrics.r2_score(y_test,X_test_pred)
print('accuracy score of test data:',score)
# Out:
# accuracy score of trained data: 1.0
# accuracy score of test data: 1.0

# %%
fore=RandomForestRegressor()

# %%
fore.fit(X_train,y_train)
X_train_pred=fore.predict(X_train)
score=metrics.r2_score(y_train,X_train_pred)
print('accuracy score of trained data:',score)

fore.fit(X_test,y_test)
X_test_pred=fore.predict(X_test)
score=metrics.r2_score(y_test,X_test_pred)
print('accuracy score of test data:',score)
# Out:
# accuracy score of trained data: 0.9917250933195317
# accuracy score of test data: 0.8711639110426928

# %%
input_data=(0,0,7,1,21950.00,21999.00,21126.05,21575.00,80,74,4159,8.965357e+07,27800.00,17273.00,13,450)
input_data_as_np=np.asarray(input_data)
reshaped=input_data_as_np.reshape(1,-1)
prediction=li.predict(reshaped)
prediction
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([21882.67266813])

# %%
print('The price is ',prediction[0])
# Out:
# The price is  21882.672668125317
