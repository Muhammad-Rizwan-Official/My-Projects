# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
cat=pd.read_csv("horse.csv")
cat
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        no  adult           530101         38.5   66.0              28.0
# 1       yes  adult           534817         39.2   88.0              20.0
# 2        no  adult           530334         38.3   40.0              24.0
# 3       yes  young          5290409         39.1  164.0              84.0
# 4        no  adult           530255         37.3  104.0              35.0
# ..      ...    ...              ...          ...    ...               ...
# 294     yes  adult           533886          NaN  120.0              70.0
# 295      no  adult           527702         37.2   72.0              24.0
# 296     yes  adult           529386         37.5   72.0              30.0
# 297     yes  adult           530612         36.5  100.0              24.0
# 298     yes  adult           534618         37.2   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# ...

# %%
cat.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
# ...

# %%
cat.tail()
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 294     yes  adult           533886          NaN  120.0              70.0
# 295      no  adult           527702         37.2   72.0              24.0
# 296     yes  adult           529386         37.5   72.0              30.0
# 297     yes  adult           530612         36.5  100.0              24.0
# 298     yes  adult           534618         37.2   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 294                cold              NaN   pale_cyanotic
# 295                cool        increased   pale_cyanotic
# 296                cold          reduced   pale_cyanotic
# 297                cool          reduced       pale_pink
# 298                 NaN              NaN             NaN
#
#     capillary_refill_time  ... packed_cell_volume total_protein  \
# 294            more_3_sec  ...               55.0          65.0
# ...

# %%
cat.shape
# Out:
# (299, 28)

# %%
cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    object
#  1   age                    299 non-null    object
#  2   hospital_number        299 non-null    int64
#  3   rectal_temp            239 non-null    float64
#  4   pulse                  275 non-null    float64
#  5   respiratory_rate       241 non-null    float64
#  6   temp_of_extremities    243 non-null    object
#  7   peripheral_pulse       230 non-null    object
#  8   mucous_membrane        252 non-null    object
#  9   capillary_refill_time  267 non-null    object
#  10  pain                   244 non-null    object
#  11  peristalsis            255 non-null    object
#  12  abdominal_distention   243 non-null    object
#  13  nasogastric_tube       195 non-null    object
# ...

# %%
cat.describe()
# Out:
#        hospital_number  rectal_temp       pulse  respiratory_rate  \
# count     2.990000e+02   239.000000  275.000000        241.000000
# mean      1.087733e+06    38.168619   72.000000         30.460581
# std       1.532032e+06     0.733744   28.646219         17.666102
# min       5.184760e+05    35.400000   30.000000          8.000000
# 25%       5.289040e+05    37.800000   48.000000         18.000000
# 50%       5.303010e+05    38.200000   64.000000         25.000000
# 75%       5.347360e+05    38.500000   88.000000         36.000000
# max       5.305629e+06    40.800000  184.000000         96.000000
#
#        nasogastric_reflux_ph  packed_cell_volume  total_protein  \
# count              53.000000          270.000000     266.000000
# mean                4.707547           46.307407      24.274436
# std                 1.982311           10.436743      27.364194
# min                 1.000000           23.000000       3.300000
# ...

# %%
cat.isnull().sum()
# Out:
# surgery                    0
# age                        0
# hospital_number            0
# rectal_temp               60
# pulse                     24
# respiratory_rate          58
# temp_of_extremities       56
# peripheral_pulse          69
# mucous_membrane           47
# capillary_refill_time     32
# pain                      55
# peristalsis               44
# abdominal_distention      56
# nasogastric_tube         104
# nasogastric_reflux       106
# nasogastric_reflux_ph    246
# rectal_exam_feces        102
# abdomen                  118
# packed_cell_volume        29
# total_protein             33
# abdomo_appearance        165
# abdomo_protein           198
# outcome                    0
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# dtype: int64

# %%
cat.isnull().sum()
# Out:
# surgery                    0
# age                        0
# hospital_number            0
# rectal_temp               60
# pulse                     24
# respiratory_rate          58
# temp_of_extremities       56
# peripheral_pulse          69
# mucous_membrane           47
# capillary_refill_time     32
# pain                      55
# peristalsis               44
# abdominal_distention      56
# nasogastric_tube         104
# nasogastric_reflux       106
# nasogastric_reflux_ph    246
# rectal_exam_feces        102
# abdomen                  118
# packed_cell_volume        29
# total_protein             33
# abdomo_appearance        165
# abdomo_protein           198
# outcome                    0
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# dtype: int64

# %%
a=cat.drop(['surgery','age','hospital_number','outcome','temp_of_extremities','abdominal_distention','nasogastric_tube','capillary_refill_time','nasogastric_reflux','peripheral_pulse','mucous_membrane'],axis=1)
a
# Out:
#      rectal_temp  pulse  respiratory_rate          pain peristalsis  \
# 0           38.5   66.0              28.0  extreme_pain      absent
# 1           39.2   88.0              20.0     mild_pain      absent
# 2           38.3   40.0              24.0     mild_pain  hypomotile
# 3           39.1  164.0              84.0     depressed      absent
# 4           37.3  104.0              35.0             0           0
# ..           ...    ...               ...           ...         ...
# 294          0.0  120.0              70.0     depressed      absent
# 295         37.2   72.0              24.0   severe_pain  hypomotile
# 296         37.5   72.0              30.0   severe_pain      absent
# 297         36.5  100.0              24.0     mild_pain  hypomotile
# 298         37.2   40.0              20.0             0           0
#
#      nasogastric_reflux_ph rectal_exam_feces        abdomen  \
# 0                      0.0         decreased  distend_large
# ...

# %%
a.value_counts(['rectal_exam_feces'])
# Out:
# rectal_exam_feces
# 0                    102
# absent                79
# normal                57
# decreased             48
# increased             13
# dtype: int64

# %%
a.replace({'rectal_exam_feces':{'absent':1,'normal':2,'decreased':3,'increased':4}},inplace=True)
a
# Out:
#      rectal_temp  pulse  respiratory_rate          pain peristalsis  \
# 0           38.5   66.0              28.0  extreme_pain      absent
# 1           39.2   88.0              20.0     mild_pain      absent
# 2           38.3   40.0              24.0     mild_pain  hypomotile
# 3           39.1  164.0              84.0     depressed      absent
# 4           37.3  104.0              35.0             0           0
# ..           ...    ...               ...           ...         ...
# 294          0.0  120.0              70.0     depressed      absent
# 295         37.2   72.0              24.0   severe_pain  hypomotile
# 296         37.5   72.0              30.0   severe_pain      absent
# 297         36.5  100.0              24.0     mild_pain  hypomotile
# 298         37.2   40.0              20.0             0           0
#
#      nasogastric_reflux_ph  rectal_exam_feces        abdomen  \
# 0                      0.0                  3  distend_large
# ...

# %%
a.value_counts(['pain'])
# Out:
# pain
# mild_pain       67
# depressed       59
# 0               55
# extreme_pain    42
# alert           38
# severe_pain     38
# dtype: int64

# %%
a.replace({'pain':{'mild_pain':1,'depressed':2,'extreme_pain':3,'alert':4,'severe_pain':5}},inplace=True)
a
# Out:
#      rectal_temp  pulse  respiratory_rate  pain peristalsis  \
# 0           38.5   66.0              28.0     3      absent
# 1           39.2   88.0              20.0     1      absent
# 2           38.3   40.0              24.0     1  hypomotile
# 3           39.1  164.0              84.0     2      absent
# 4           37.3  104.0              35.0     0           0
# ..           ...    ...               ...   ...         ...
# 294          0.0  120.0              70.0     2      absent
# 295         37.2   72.0              24.0     5  hypomotile
# 296         37.5   72.0              30.0     5      absent
# 297         36.5  100.0              24.0     1  hypomotile
# 298         37.2   40.0              20.0     0           0
#
#      nasogastric_reflux_ph  rectal_exam_feces        abdomen  \
# 0                      0.0                  3  distend_large
# 1                      0.0                  1          other
# ...

# %%
a.value_counts(['peristalsis'])
# Out:
# peristalsis
# hypomotile     127
# absent          73
# 0               44
# hypermotile     39
# normal          16
# dtype: int64

# %%
a.replace({'peristalsis':{'hypomotile':1,'absent':2,'hypermotile':3,'normal':4}},inplace=True)
a
# Out:
#      rectal_temp  pulse  respiratory_rate  pain  peristalsis  \
# 0           38.5   66.0              28.0     3            2
# 1           39.2   88.0              20.0     1            2
# 2           38.3   40.0              24.0     1            1
# 3           39.1  164.0              84.0     2            2
# 4           37.3  104.0              35.0     0            0
# ..           ...    ...               ...   ...          ...
# 294          0.0  120.0              70.0     2            2
# 295         37.2   72.0              24.0     5            1
# 296         37.5   72.0              30.0     5            2
# 297         36.5  100.0              24.0     1            1
# 298         37.2   40.0              20.0     0            0
#
#      nasogastric_reflux_ph  rectal_exam_feces        abdomen  \
# 0                      0.0                  3  distend_large
# 1                      0.0                  1          other
# ...

# %%
a.value_counts(['abdomen'])
# Out:
# abdomen
# 0                118
# distend_large     78
# distend_small     43
# normal            28
# other             19
# firm              13
# dtype: int64

# %%
a.replace({'abdomen':{'distend_large':1,'distend_small':2,'normal':3,'other':4,'firm':5}},inplace=True)
a
# Out:
#      rectal_temp  pulse  respiratory_rate  pain  peristalsis  \
# 0           38.5   66.0              28.0     3            2
# 1           39.2   88.0              20.0     1            2
# 2           38.3   40.0              24.0     1            1
# 3           39.1  164.0              84.0     2            2
# 4           37.3  104.0              35.0     0            0
# ..           ...    ...               ...   ...          ...
# 294          0.0  120.0              70.0     2            2
# 295         37.2   72.0              24.0     5            1
# 296         37.5   72.0              30.0     5            2
# 297         36.5  100.0              24.0     1            1
# 298         37.2   40.0              20.0     0            0
#
#      nasogastric_reflux_ph  rectal_exam_feces  abdomen  packed_cell_volume  \
# 0                      0.0                  3        1                45.0
# 1                      0.0                  1        4                50.0
# ...

# %%
a.value_counts(['abdomo_appearance'])
# Out:
# abdomo_appearance
# 0                    165
# cloudy                47
# serosanguious         46
# clear                 41
# dtype: int64

# %%
a.replace({'abdomo_appearance':{'cloudy':1,'serosanguious':2,'clear':3}},inplace=True)
a
# Out:
#      rectal_temp  pulse  respiratory_rate  pain  peristalsis  \
# 0           38.5   66.0              28.0     3            2
# 1           39.2   88.0              20.0     1            2
# 2           38.3   40.0              24.0     1            1
# 3           39.1  164.0              84.0     2            2
# 4           37.3  104.0              35.0     0            0
# ..           ...    ...               ...   ...          ...
# 294          0.0  120.0              70.0     2            2
# 295         37.2   72.0              24.0     5            1
# 296         37.5   72.0              30.0     5            2
# 297         36.5  100.0              24.0     1            1
# 298         37.2   40.0              20.0     0            0
#
#      nasogastric_reflux_ph  rectal_exam_feces  abdomen  packed_cell_volume  \
# 0                      0.0                  3        1                45.0
# 1                      0.0                  1        4                50.0
# ...

# %%
a.value_counts(['surgical_lesion'])
# Out:
# surgical_lesion
# yes                190
# no                 109
# dtype: int64

# %%
a.replace({'surgical_lesion':{'no':0,'yes':1}},inplace=True)
a
# Out:
#      rectal_temp  pulse  respiratory_rate  pain  peristalsis  \
# 0           38.5   66.0              28.0     3            2
# 1           39.2   88.0              20.0     1            2
# 2           38.3   40.0              24.0     1            1
# 3           39.1  164.0              84.0     2            2
# 4           37.3  104.0              35.0     0            0
# ..           ...    ...               ...   ...          ...
# 294          0.0  120.0              70.0     2            2
# 295         37.2   72.0              24.0     5            1
# 296         37.5   72.0              30.0     5            2
# 297         36.5  100.0              24.0     1            1
# 298         37.2   40.0              20.0     0            0
#
#      nasogastric_reflux_ph  rectal_exam_feces  abdomen  packed_cell_volume  \
# 0                      0.0                  3        1                45.0
# 1                      0.0                  1        4                50.0
# ...

# %%
a.replace({'cp_data':{'no':0,'yes':1}},inplace=True)
a
# Out:
#      rectal_temp  pulse  respiratory_rate  pain  peristalsis  \
# 0           38.5   66.0              28.0     3            2
# 1           39.2   88.0              20.0     1            2
# 2           38.3   40.0              24.0     1            1
# 3           39.1  164.0              84.0     2            2
# 4           37.3  104.0              35.0     0            0
# ..           ...    ...               ...   ...          ...
# 294          0.0  120.0              70.0     2            2
# 295         37.2   72.0              24.0     5            1
# 296         37.5   72.0              30.0     5            2
# 297         36.5  100.0              24.0     1            1
# 298         37.2   40.0              20.0     0            0
#
#      nasogastric_reflux_ph  rectal_exam_feces  abdomen  packed_cell_volume  \
# 0                      0.0                  3        1                45.0
# 1                      0.0                  1        4                50.0
# ...

# %%
y=a['cp_data']
y
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 294    0
# 295    1
# 296    0
# 297    1
# 298    0
# Name: cp_data, Length: 299, dtype: int64

# %%
x=a.drop(['cp_data'],axis=1)
x
# Out:
#      rectal_temp  pulse  respiratory_rate  pain  peristalsis  \
# 0           38.5   66.0              28.0     3            2
# 1           39.2   88.0              20.0     1            2
# 2           38.3   40.0              24.0     1            1
# 3           39.1  164.0              84.0     2            2
# 4           37.3  104.0              35.0     0            0
# ..           ...    ...               ...   ...          ...
# 294          0.0  120.0              70.0     2            2
# 295         37.2   72.0              24.0     5            1
# 296         37.5   72.0              30.0     5            2
# 297         36.5  100.0              24.0     1            1
# 298         37.2   40.0              20.0     0            0
#
#      nasogastric_reflux_ph  rectal_exam_feces  abdomen  packed_cell_volume  \
# 0                      0.0                  3        1                45.0
# 1                      0.0                  1        4                50.0
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x.shape,X_train.shape,X_test.shape
# Out:
# ((299, 16), (224, 16), (75, 16))

# %%
tree=DecisionTreeClassifier()

# %%
tree.fit(X_train,y_train)
X_train_pred=tree.predict(X_train)
score=accuracy_score(y_train,X_train_pred)
print('accuracy score of trained data:',score)

tree.fit(X_test,y_test)
X_test_pred=tree.predict(X_test)
score=accuracy_score(y_test,X_test_pred)
print('accuracy score of test data:',score)
# Out:
# accuracy score of trained data: 1.0
# accuracy score of test data: 1.0

# %%
forest=RandomForestClassifier()

# %%
forest.fit(X_train,y_train)
X_train_pred=forest.predict(X_train)
score=accuracy_score(y_train,X_train_pred)
print('accuracy score of trained data:',score)

forest.fit(X_test,y_test)
X_test_pred=forest.predict(X_test)
score=accuracy_score(y_test,X_test_pred)
print('accuracy score of test data:',score)
# Out:
# accuracy score of trained data: 1.0
# accuracy score of test data: 1.0

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(X_train,y_train)
X_train_pred=knn.predict(X_train)
score=accuracy_score(y_train,X_train_pred)
print('accuracy score of trained data:',score)

knn.fit(X_test,y_test)
X_test_pred=knn.predict(X_test)
score=accuracy_score(y_test,X_test_pred)
print('accuracy score of test data:',score)
# Out:
# accuracy score of trained data: 0.7678571428571429
# accuracy score of test data: 0.76
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
input_data=(39.1,164.0,84.0,2,2,5.0,3,0,48.0,7.2,2,5.3,1,2208,0,0)
input_as_np=np.asarray(input_data)
reshaped=input_as_np.reshape(1,-1)
prediction=forest.predict(reshaped)
prediction
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
if(prediction[0]==1):
    print("Have Cattle Disease")
else:
    print("No disease")
# Out:
# Have Cattle Disease
